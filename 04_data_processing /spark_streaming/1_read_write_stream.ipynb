# %% [markdown]
# <a href="https://colab.research.google.com/github/carsofferrei/04_data_processing/blob/main/04_data_processing%20/spark_streaming/1_read_write_stream.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Read & Write Stream
# - readStream()
# - writeStream()
# - Streaming Dataframe

# %% [markdown]
# # Setting up PySpark

# %%
# %pip install pyspark
# Out:
# Requirement already satisfied: pyspark in /usr/local/lib/python3.10/dist-packages (3.5.3)
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.master('local').appName('Test streaming').getOrCreate()

# %% [markdown]
# # readStream with format "rate"
# - readStream
# - format("rate")

# %%
import pyspark.sql.functions as F

# read stream
stream = spark.readStream.format("rate").load()

# %%
type(stream)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
# checking if it's streaming dataframe
stream.isStreaming
# Out:
# True

# %%
# should be false
data = [("c1", "v1"), ("c2", "v2")]
columns = ["col1", "col2"]
df = spark.createDataFrame(data, columns)
df.isStreaming
# Out:
# False

# %%
# apply normal dataframe operations
stream.printSchema()
# Out:
# root
#  |-- timestamp: timestamp (nullable = true)
#  |-- value: long (nullable = true)

# %%
# Queries with streaming sources must be executed with writeStream.start();
# stream.show()
stream.count()
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# <ipython-input-8-2c876bdc4c4f> in <cell line: 3>()
#       1 # Queries with streaming sources must be executed with writeStream.start();
#       2 # stream.show()
# ----> 3 stream.count()
#
# /usr/local/lib/python3.10/dist-packages/pyspark/sql/dataframe.py in count(self)
#    1238         3
#    1239         """
# -> 1240         return int(self._jdf.count())
#    1241
#    1242     def collect(self) -> List[Row]:
#
# /usr/local/lib/python3.10/dist-packages/py4j/java_gateway.py in __call__(self, *args)
#    1320
#    1321         answer = self.gateway_client.send_command(command)
# -> 1322         return_value = get_return_value(
#    1323             answer, self.gateway_client, self.target_id, self.name)
#    1324
#
# /usr/local/lib/python3.10/dist-packages/pyspark/errors/exceptions/captured.py in deco(*a, **kw)
#     183                 # Hide where the exception came from that shows a non-Pythonic
#     184                 # JVM exception message.
# --> 185                 raise converted from None
#     186             else:
#     187                 raise
#
# AnalysisException: Queries with streaming sources must be executed with writeStream.start();
# rate

# %% [markdown]
# # Transfor streaming dataframe

# %%
transformed = stream.withColumn("value2", F.col("value") * 2)

# %%
transformed.isStreaming
# Out:
# True

# %% [markdown]
# # write streaming dataframe - format memory
# - writeStream
# - format("memory")
# - queryName
# - outputMode
# - start

# %%
query = (transformed.writeStream
  .format('memory')
  .queryName('rate_report')
  .outputMode('append') # Para cada linha estou a adiciona-la essa nova linha no "producer" - que é o nosso rate.
  # Se eu tivesse uma agregação, o melhor seria aplicar um complete
  .start()
)

# %% [markdown]
# # Checking result table

# %%
# StreamingQuery
type(query)
# Out:
# pyspark.sql.streaming.query.StreamingQuery

# %%
import pyspark.sql.functions as F

# print(spark.table("rate_report").count())
# spark.table("rate_report").sort(F.col("timestamp").desc()).show(20, False)

# one line per second


print(spark.table("rate_report").count())
spark.table("rate_report").sort(F.col("timestamp").desc()).show(100)
# Out:
# 948
# +--------------------+-----+------+
# |           timestamp|value|value2|
# +--------------------+-----+------+
# |2024-11-23 14:21:...|  947|  1894|
# |2024-11-23 14:21:...|  946|  1892|
# |2024-11-23 14:21:...|  945|  1890|
# |2024-11-23 14:21:...|  944|  1888|
# |2024-11-23 14:21:...|  943|  1886|
# |2024-11-23 14:21:...|  942|  1884|
# |2024-11-23 14:21:...|  941|  1882|
# |2024-11-23 14:21:...|  940|  1880|
# |2024-11-23 14:21:...|  939|  1878|
# |2024-11-23 14:21:...|  938|  1876|
# |2024-11-23 14:21:...|  937|  1874|
# |2024-11-23 14:21:...|  936|  1872|
# |2024-11-23 14:21:...|  935|  1870|
# |2024-11-23 14:21:...|  934|  1868|
# |2024-11-23 14:21:...|  933|  1866|
# |2024-11-23 14:21:...|  932|  1864|
# |2024-11-23 14:21:...|  931|  1862|
# |2024-11-23 14:21:...|  930|  1860|
# |2024-11-23 14:19:...|  862|  1724|
# |2024-11-23 14:19:...|  861|  1722|
# |2024-11-23 14:19:...|  860|  1720|
# |2024-11-23 14:19:...|  859|  1718|
# |2024-11-23 14:19:...|  858|  1716|
# |2024-11-23 14:19:...|  857|  1714|
# |2024-11-23 14:19:...|  856|  1712|
# |2024-11-23 14:19:...|  855|  1710|
# |2024-11-23 14:19:...|  854|  1708|
# |2024-11-23 14:19:...|  853|  1706|
# |2024-11-23 14:19:...|  852|  1704|
# |2024-11-23 14:19:...|  851|  1702|
# |2024-11-23 14:19:...|  850|  1700|
# |2024-11-23 14:19:...|  849|  1698|
# |2024-11-23 14:19:...|  848|  1696|
# +--------------------+-----+------+
# only showing top 100 rows

# %%
query.status
# Podemos tanto ter uma mensagem de 'Processing new data' como 'aiting for data to arrive'
# Quando falha costuma aparecer uma mensagem quando este comando corre
# Out:
# {'message': 'Waiting for data to arrive',
#  'isDataAvailable': False,
#  'isTriggerActive': False}

# %%
query.isActive
# Out:
# True

# %%
query.recentProgress
# Out:
# [{'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:38.748Z',
#   'batchId': 187,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 9.803921568627452,
#   'durationMs': {'addBatch': 39,
#    'commitOffsets': 29,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 6,
#    'triggerExecution': 102,
#    'walCommit': 28},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 187,
#     'endOffset': 188,
#     'latestOffset': 188,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 9.803921568627452}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:39.748Z',
#   'batchId': 188,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 10.416666666666666,
#   'durationMs': {'addBatch': 34,
#    'commitOffsets': 27,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 6,
#    'triggerExecution': 96,
#    'walCommit': 29},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 188,
#     'endOffset': 189,
#     'latestOffset': 189,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 10.416666666666666}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:40.745Z',
#   'batchId': 189,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 8.19672131147541,
#   'durationMs': {'addBatch': 48,
#    'commitOffsets': 32,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 8,
#    'triggerExecution': 122,
#    'walCommit': 34},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 189,
#     'endOffset': 190,
#     'latestOffset': 190,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 8.19672131147541}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:41.740Z',
#   'batchId': 190,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 7.194244604316546,
#   'durationMs': {'addBatch': 59,
#    'commitOffsets': 45,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 6,
#    'triggerExecution': 139,
#    'walCommit': 28},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 190,
#     'endOffset': 191,
#     'latestOffset': 191,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 7.194244604316546}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:42.740Z',
#   'batchId': 191,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 9.25925925925926,
#   'durationMs': {'addBatch': 33,
#    'commitOffsets': 40,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 6,
#    'triggerExecution': 108,
#    'walCommit': 29},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 191,
#     'endOffset': 192,
#     'latestOffset': 192,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 9.25925925925926}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:43.745Z',
#   'batchId': 192,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 4.761904761904762,
#   'durationMs': {'addBatch': 66,
#    'commitOffsets': 91,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 9,
#    'triggerExecution': 210,
#    'walCommit': 44},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 192,
#     'endOffset': 193,
#     'latestOffset': 193,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 4.761904761904762}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:44.740Z',
#   'batchId': 193,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 3.952569169960474,
#   'durationMs': {'addBatch': 77,
#    'commitOffsets': 111,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 21,
#    'triggerExecution': 253,
#    'walCommit': 43},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 193,
#     'endOffset': 194,
#     'latestOffset': 194,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 3.952569169960474}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:45.747Z',
#   'batchId': 194,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 8.333333333333334,
#   'durationMs': {'addBatch': 40,
#    'commitOffsets': 46,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 6,
#    'triggerExecution': 120,
#    'walCommit': 28},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 194,
#     'endOffset': 195,
#     'latestOffset': 195,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 8.333333333333334}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:46.745Z',
#   'batchId': 195,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 6.578947368421053,
#   'durationMs': {'addBatch': 61,
#    'commitOffsets': 56,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 152,
#    'walCommit': 28},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 195,
#     'endOffset': 196,
#     'latestOffset': 196,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 6.578947368421053}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:47.740Z',
#   'batchId': 196,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 8.264462809917356,
#   'durationMs': {'addBatch': 42,
#    'commitOffsets': 44,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 7,
#    'triggerExecution': 121,
#    'walCommit': 28},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 196,
#     'endOffset': 197,
#     'latestOffset': 197,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 8.264462809917356}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:48.748Z',
#   'batchId': 197,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 10.989010989010989,
#   'durationMs': {'addBatch': 30,
#    'commitOffsets': 27,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 7,
#    'triggerExecution': 91,
#    'walCommit': 27},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 197,
#     'endOffset': 198,
#     'latestOffset': 198,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 10.989010989010989}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:49.748Z',
#   'batchId': 198,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 8.695652173913043,
#   'durationMs': {'addBatch': 41,
#    'commitOffsets': 32,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 7,
#    'triggerExecution': 115,
#    'walCommit': 35},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 198,
#     'endOffset': 199,
#     'latestOffset': 199,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 8.695652173913043}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:50.740Z',
#   'batchId': 199,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 8.695652173913043,
#   'durationMs': {'addBatch': 40,
#    'commitOffsets': 35,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 7,
#    'triggerExecution': 115,
#    'walCommit': 32},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 199,
#     'endOffset': 200,
#     'latestOffset': 200,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 8.695652173913043}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:51.741Z',
#   'batchId': 200,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 3.597122302158273,
#   'durationMs': {'addBatch': 65,
#    'commitOffsets': 178,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 278,
#    'walCommit': 27},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 200,
#     'endOffset': 201,
#     'latestOffset': 201,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 3.597122302158273}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:52.741Z',
#   'batchId': 201,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 8.695652173913043,
#   'durationMs': {'addBatch': 38,
#    'commitOffsets': 35,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 7,
#    'triggerExecution': 115,
#    'walCommit': 34},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 201,
#     'endOffset': 202,
#     'latestOffset': 202,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 8.695652173913043}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:53.741Z',
#   'batchId': 202,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 9.708737864077671,
#   'durationMs': {'addBatch': 34,
#    'commitOffsets': 35,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 6,
#    'triggerExecution': 103,
#    'walCommit': 28},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 202,
#     'endOffset': 203,
#     'latestOffset': 203,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 9.708737864077671}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:54.745Z',
#   'batchId': 203,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 9.900990099009901,
#   'durationMs': {'addBatch': 36,
#    'commitOffsets': 28,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 101,
#    'walCommit': 32},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 203,
#     'endOffset': 204,
#     'latestOffset': 204,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 9.900990099009901}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:55.746Z',
#   'batchId': 204,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 6.578947368421053,
#   'durationMs': {'addBatch': 57,
#    'commitOffsets': 40,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 9,
#    'triggerExecution': 152,
#    'walCommit': 45},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 204,
#     'endOffset': 205,
#     'latestOffset': 205,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 6.578947368421053}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:56.743Z',
#   'batchId': 205,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 3.7037037037037033,
#   'durationMs': {'addBatch': 96,
#    'commitOffsets': 126,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 8,
#    'triggerExecution': 270,
#    'walCommit': 39},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 205,
#     'endOffset': 206,
#     'latestOffset': 206,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 3.7037037037037033}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:57.745Z',
#   'batchId': 206,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 10.204081632653061,
#   'durationMs': {'addBatch': 34,
#    'commitOffsets': 31,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 6,
#    'triggerExecution': 98,
#    'walCommit': 27},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 206,
#     'endOffset': 207,
#     'latestOffset': 207,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 10.204081632653061}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:58.741Z',
#   'batchId': 207,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 10.869565217391305,
#   'durationMs': {'addBatch': 30,
#    'commitOffsets': 28,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 92,
#    'walCommit': 28},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 207,
#     'endOffset': 208,
#     'latestOffset': 208,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 10.869565217391305}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:59.741Z',
#   'batchId': 208,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 7.874015748031496,
#   'durationMs': {'addBatch': 42,
#    'commitOffsets': 47,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 7,
#    'triggerExecution': 127,
#    'walCommit': 30},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 208,
#     'endOffset': 209,
#     'latestOffset': 209,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 7.874015748031496}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:00.746Z',
#   'batchId': 209,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 8.333333333333334,
#   'durationMs': {'addBatch': 40,
#    'commitOffsets': 45,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 6,
#    'triggerExecution': 120,
#    'walCommit': 29},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 209,
#     'endOffset': 210,
#     'latestOffset': 210,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 8.333333333333334}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:01.744Z',
#   'batchId': 210,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 7.4074074074074066,
#   'durationMs': {'addBatch': 54,
#    'commitOffsets': 44,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 6,
#    'triggerExecution': 135,
#    'walCommit': 29},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 210,
#     'endOffset': 211,
#     'latestOffset': 211,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 7.4074074074074066}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:02.747Z',
#   'batchId': 211,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 10.309278350515463,
#   'durationMs': {'addBatch': 31,
#    'commitOffsets': 27,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 97,
#    'walCommit': 32},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 211,
#     'endOffset': 212,
#     'latestOffset': 212,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 10.309278350515463}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:03.742Z',
#   'batchId': 212,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 9.523809523809524,
#   'durationMs': {'addBatch': 34,
#    'commitOffsets': 29,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 10,
#    'triggerExecution': 105,
#    'walCommit': 30},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 212,
#     'endOffset': 213,
#     'latestOffset': 213,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 9.523809523809524}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:04.745Z',
#   'batchId': 213,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 8.771929824561402,
#   'durationMs': {'addBatch': 42,
#    'commitOffsets': 38,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 6,
#    'triggerExecution': 114,
#    'walCommit': 28},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 213,
#     'endOffset': 214,
#     'latestOffset': 214,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 8.771929824561402}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:05.743Z',
#   'batchId': 214,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 8.19672131147541,
#   'durationMs': {'addBatch': 38,
#    'commitOffsets': 43,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 7,
#    'triggerExecution': 122,
#    'walCommit': 34},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 214,
#     'endOffset': 215,
#     'latestOffset': 215,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 8.19672131147541}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:06.750Z',
#   'batchId': 215,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 3.8314176245210727,
#   'durationMs': {'addBatch': 64,
#    'commitOffsets': 157,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 6,
#    'triggerExecution': 261,
#    'walCommit': 33},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 215,
#     'endOffset': 216,
#     'latestOffset': 216,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 3.8314176245210727}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:07.741Z',
#   'batchId': 216,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 5.524861878453039,
#   'durationMs': {'addBatch': 81,
#    'commitOffsets': 43,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 14,
#    'triggerExecution': 181,
#    'walCommit': 42},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 216,
#     'endOffset': 217,
#     'latestOffset': 217,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 5.524861878453039}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:08.745Z',
#   'batchId': 217,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 8.0,
#   'durationMs': {'addBatch': 37,
#    'commitOffsets': 40,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 7,
#    'triggerExecution': 125,
#    'walCommit': 41},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 217,
#     'endOffset': 218,
#     'latestOffset': 218,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 8.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:09.746Z',
#   'batchId': 218,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 11.11111111111111,
#   'durationMs': {'addBatch': 28,
#    'commitOffsets': 28,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 90,
#    'walCommit': 27},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 218,
#     'endOffset': 219,
#     'latestOffset': 219,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 11.11111111111111}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:10.743Z',
#   'batchId': 219,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 10.989010989010989,
#   'durationMs': {'addBatch': 30,
#    'commitOffsets': 27,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 91,
#    'walCommit': 28},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 219,
#     'endOffset': 220,
#     'latestOffset': 220,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 10.989010989010989}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:11.742Z',
#   'batchId': 220,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 6.849315068493151,
#   'durationMs': {'addBatch': 56,
#    'commitOffsets': 54,
#    'getBatch': 1,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 146,
#    'walCommit': 29},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 220,
#     'endOffset': 221,
#     'latestOffset': 221,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 6.849315068493151}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:12.744Z',
#   'batchId': 221,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 10.638297872340425,
#   'durationMs': {'addBatch': 31,
#    'commitOffsets': 29,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 6,
#    'triggerExecution': 94,
#    'walCommit': 28},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 221,
#     'endOffset': 222,
#     'latestOffset': 222,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 10.638297872340425}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:13.745Z',
#   'batchId': 222,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 9.615384615384615,
#   'durationMs': {'addBatch': 30,
#    'commitOffsets': 39,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 6,
#    'triggerExecution': 104,
#    'walCommit': 28},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 222,
#     'endOffset': 223,
#     'latestOffset': 223,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 9.615384615384615}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:14.747Z',
#   'batchId': 223,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 11.363636363636365,
#   'durationMs': {'addBatch': 28,
#    'commitOffsets': 27,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 88,
#    'walCommit': 28},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 223,
#     'endOffset': 224,
#     'latestOffset': 224,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 11.363636363636365}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:15.743Z',
#   'batchId': 224,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 9.900990099009901,
#   'durationMs': {'addBatch': 31,
#    'commitOffsets': 35,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 101,
#    'walCommit': 28},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 224,
#     'endOffset': 225,
#     'latestOffset': 225,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 9.900990099009901}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:16.741Z',
#   'batchId': 225,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 7.518796992481203,
#   'durationMs': {'addBatch': 55,
#    'commitOffsets': 44,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 6,
#    'triggerExecution': 133,
#    'walCommit': 28},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 225,
#     'endOffset': 226,
#     'latestOffset': 226,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 7.518796992481203}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:17.745Z',
#   'batchId': 226,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 6.993006993006993,
#   'durationMs': {'addBatch': 51,
#    'commitOffsets': 48,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 6,
#    'triggerExecution': 143,
#    'walCommit': 36},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 226,
#     'endOffset': 227,
#     'latestOffset': 227,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 6.993006993006993}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:18.748Z',
#   'batchId': 227,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 9.523809523809524,
#   'durationMs': {'addBatch': 33,
#    'commitOffsets': 37,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 6,
#    'triggerExecution': 105,
#    'walCommit': 28},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 227,
#     'endOffset': 228,
#     'latestOffset': 228,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 9.523809523809524}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:19.740Z',
#   'batchId': 228,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 5.780346820809249,
#   'durationMs': {'addBatch': 77,
#    'commitOffsets': 45,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 7,
#    'triggerExecution': 173,
#    'walCommit': 43},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 228,
#     'endOffset': 229,
#     'latestOffset': 229,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 5.780346820809249}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:20.740Z',
#   'batchId': 229,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 5.847953216374268,
#   'durationMs': {'addBatch': 69,
#    'commitOffsets': 47,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 10,
#    'triggerExecution': 171,
#    'walCommit': 45},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 229,
#     'endOffset': 230,
#     'latestOffset': 230,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 5.847953216374268}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:21.740Z',
#   'batchId': 230,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 4.405286343612334,
#   'durationMs': {'addBatch': 75,
#    'commitOffsets': 110,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 6,
#    'triggerExecution': 227,
#    'walCommit': 34},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 230,
#     'endOffset': 231,
#     'latestOffset': 231,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 4.405286343612334}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:22.745Z',
#   'batchId': 231,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 8.333333333333334,
#   'durationMs': {'addBatch': 40,
#    'commitOffsets': 35,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 8,
#    'triggerExecution': 120,
#    'walCommit': 35},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 231,
#     'endOffset': 232,
#     'latestOffset': 232,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 8.333333333333334}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:23.745Z',
#   'batchId': 232,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 9.708737864077671,
#   'durationMs': {'addBatch': 41,
#    'commitOffsets': 28,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 6,
#    'triggerExecution': 103,
#    'walCommit': 28},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 232,
#     'endOffset': 233,
#     'latestOffset': 233,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 9.708737864077671}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:24.741Z',
#   'batchId': 233,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 7.936507936507937,
#   'durationMs': {'addBatch': 40,
#    'commitOffsets': 45,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 7,
#    'triggerExecution': 126,
#    'walCommit': 34},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 233,
#     'endOffset': 234,
#     'latestOffset': 234,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 7.936507936507937}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:25.741Z',
#   'batchId': 234,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 7.518796992481203,
#   'durationMs': {'addBatch': 51,
#    'commitOffsets': 43,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 6,
#    'triggerExecution': 133,
#    'walCommit': 32},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 234,
#     'endOffset': 235,
#     'latestOffset': 235,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 7.518796992481203}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:26.745Z',
#   'batchId': 235,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 3.125,
#   'durationMs': {'addBatch': 102,
#    'commitOffsets': 132,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 10,
#    'triggerExecution': 320,
#    'walCommit': 75},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 235,
#     'endOffset': 236,
#     'latestOffset': 236,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 3.125}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:27.747Z',
#   'batchId': 236,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 8.474576271186441,
#   'durationMs': {'addBatch': 42,
#    'commitOffsets': 33,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 7,
#    'triggerExecution': 118,
#    'walCommit': 34},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 236,
#     'endOffset': 237,
#     'latestOffset': 237,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 8.474576271186441}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:28.749Z',
#   'batchId': 237,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 7.575757575757575,
#   'durationMs': {'addBatch': 47,
#    'commitOffsets': 46,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 6,
#    'triggerExecution': 132,
#    'walCommit': 32},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 237,
#     'endOffset': 238,
#     'latestOffset': 238,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 7.575757575757575}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:29.748Z',
#   'batchId': 238,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 10.416666666666666,
#   'durationMs': {'addBatch': 36,
#    'commitOffsets': 27,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 96,
#    'walCommit': 27},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 238,
#     'endOffset': 239,
#     'latestOffset': 239,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 10.416666666666666}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:30.749Z',
#   'batchId': 239,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 10.638297872340425,
#   'durationMs': {'addBatch': 32,
#    'commitOffsets': 28,
#    'getBatch': 1,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 94,
#    'walCommit': 28},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 239,
#     'endOffset': 240,
#     'latestOffset': 240,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 10.638297872340425}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:31.747Z',
#   'batchId': 240,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 2.3923444976076556,
#   'durationMs': {'addBatch': 84,
#    'commitOffsets': 285,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 6,
#    'triggerExecution': 418,
#    'walCommit': 41},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 240,
#     'endOffset': 241,
#     'latestOffset': 241,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 2.3923444976076556}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:32.742Z',
#   'batchId': 241,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 6.944444444444445,
#   'durationMs': {'addBatch': 47,
#    'commitOffsets': 43,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 7,
#    'triggerExecution': 144,
#    'walCommit': 46},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 241,
#     'endOffset': 242,
#     'latestOffset': 242,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 6.944444444444445}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:33.742Z',
#   'batchId': 242,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 6.756756756756757,
#   'durationMs': {'addBatch': 47,
#    'commitOffsets': 34,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 27,
#    'triggerExecution': 148,
#    'walCommit': 39},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 242,
#     'endOffset': 243,
#     'latestOffset': 243,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 6.756756756756757}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:34.744Z',
#   'batchId': 243,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 8.064516129032258,
#   'durationMs': {'addBatch': 36,
#    'commitOffsets': 53,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 6,
#    'triggerExecution': 124,
#    'walCommit': 29},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 243,
#     'endOffset': 244,
#     'latestOffset': 244,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 8.064516129032258}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:35.742Z',
#   'batchId': 244,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 10.1010101010101,
#   'durationMs': {'addBatch': 33,
#    'commitOffsets': 30,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 99,
#    'walCommit': 31},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 244,
#     'endOffset': 245,
#     'latestOffset': 245,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 10.1010101010101}],
# ...
#     'startOffset': 266,
#     'endOffset': 267,
#     'latestOffset': 267,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 9.523809523809524}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:58.742Z',
#   'batchId': 267,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 8.695652173913043,
#   'durationMs': {'addBatch': 37,
#    'commitOffsets': 34,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 8,
#    'triggerExecution': 115,
#    'walCommit': 36},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 267,
#     'endOffset': 268,
#     'latestOffset': 268,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 8.695652173913043}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:59.745Z',
#   'batchId': 268,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 9.345794392523365,
#   'durationMs': {'addBatch': 37,
#    'commitOffsets': 33,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 7,
#    'triggerExecution': 107,
#    'walCommit': 28},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 268,
#     'endOffset': 269,
#     'latestOffset': 269,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 9.345794392523365}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:10:00.740Z',
#   'batchId': 269,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 9.523809523809524,
#   'durationMs': {'addBatch': 31,
#    'commitOffsets': 33,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 105,
#    'walCommit': 36},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 269,
#     'endOffset': 270,
#     'latestOffset': 270,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 9.523809523809524}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:10:01.742Z',
#   'batchId': 270,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 3.558718861209964,
#   'durationMs': {'addBatch': 52,
#    'commitOffsets': 195,
#    'getBatch': 1,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 281,
#    'walCommit': 28},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 270,
#     'endOffset': 271,
#     'latestOffset': 271,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 3.558718861209964}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:10:02.746Z',
#   'batchId': 271,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 8.474576271186441,
#   'durationMs': {'addBatch': 40,
#    'commitOffsets': 34,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 7,
#    'triggerExecution': 118,
#    'walCommit': 36},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 271,
#     'endOffset': 272,
#     'latestOffset': 272,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 8.474576271186441}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:10:03.743Z',
#   'batchId': 272,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 9.708737864077671,
#   'durationMs': {'addBatch': 42,
#    'commitOffsets': 27,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 6,
#    'triggerExecution': 103,
#    'walCommit': 28},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 272,
#     'endOffset': 273,
#     'latestOffset': 273,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 9.708737864077671}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:10:04.748Z',
#   'batchId': 273,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 6.756756756756757,
#   'durationMs': {'addBatch': 53,
#    'commitOffsets': 50,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 8,
#    'triggerExecution': 148,
#    'walCommit': 36},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 273,
#     'endOffset': 274,
#     'latestOffset': 274,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 6.756756756756757}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:10:05.740Z',
#   'batchId': 274,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 8.547008547008547,
#   'durationMs': {'addBatch': 38,
#    'commitOffsets': 44,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 6,
#    'triggerExecution': 117,
#    'walCommit': 29},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 274,
#     'endOffset': 275,
#     'latestOffset': 275,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 8.547008547008547}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:10:06.745Z',
#   'batchId': 275,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 7.518796992481203,
#   'durationMs': {'addBatch': 48,
#    'commitOffsets': 50,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 133,
#    'walCommit': 28},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 275,
#     'endOffset': 276,
#     'latestOffset': 276,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 7.518796992481203}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:10:07.745Z',
#   'batchId': 276,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 5.524861878453039,
#   'durationMs': {'addBatch': 43,
#    'commitOffsets': 86,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 7,
#    'triggerExecution': 181,
#    'walCommit': 45},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 276,
#     'endOffset': 277,
#     'latestOffset': 277,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 5.524861878453039}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:10:08.743Z',
#   'batchId': 277,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 5.555555555555555,
#   'durationMs': {'addBatch': 85,
#    'commitOffsets': 47,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 6,
#    'triggerExecution': 180,
#    'walCommit': 41},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 277,
#     'endOffset': 278,
#     'latestOffset': 278,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 5.555555555555555}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:10:09.748Z',
#   'batchId': 278,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 11.235955056179776,
#   'durationMs': {'addBatch': 27,
#    'commitOffsets': 29,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 89,
#    'walCommit': 28},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 278,
#     'endOffset': 279,
#     'latestOffset': 279,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 11.235955056179776}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:10:10.748Z',
#   'batchId': 279,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 9.174311926605505,
#   'durationMs': {'addBatch': 33,
#    'commitOffsets': 33,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 7,
#    'triggerExecution': 109,
#    'walCommit': 35},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 279,
#     'endOffset': 280,
#     'latestOffset': 280,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 9.174311926605505}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:10:11.742Z',
#   'batchId': 280,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 7.8125,
#   'durationMs': {'addBatch': 48,
#    'commitOffsets': 45,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 6,
#    'triggerExecution': 128,
#    'walCommit': 29},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 280,
#     'endOffset': 281,
#     'latestOffset': 281,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 7.8125}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:10:12.747Z',
#   'batchId': 281,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 9.708737864077671,
#   'durationMs': {'addBatch': 31,
#    'commitOffsets': 38,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 103,
#    'walCommit': 29},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 281,
#     'endOffset': 282,
#     'latestOffset': 282,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 9.708737864077671}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:10:13.749Z',
#   'batchId': 282,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 8.547008547008547,
#   'durationMs': {'addBatch': 36,
#    'commitOffsets': 45,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 6,
#    'triggerExecution': 117,
#    'walCommit': 29},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 282,
#     'endOffset': 283,
#     'latestOffset': 283,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 8.547008547008547}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:10:14.744Z',
#   'batchId': 283,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 11.363636363636365,
#   'durationMs': {'addBatch': 25,
#    'commitOffsets': 29,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 6,
#    'triggerExecution': 88,
#    'walCommit': 28},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 283,
#     'endOffset': 284,
#     'latestOffset': 284,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 11.363636363636365}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:10:15.741Z',
#   'batchId': 284,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 9.900990099009901,
#   'durationMs': {'addBatch': 27,
#    'commitOffsets': 38,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 101,
#    'walCommit': 30},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 284,
#     'endOffset': 285,
#     'latestOffset': 285,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 9.900990099009901}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '67e7f66c-c29d-491d-99c2-11dcd1e575d7',
#   'runId': 'feba535d-ce69-451d-a919-1530c790af11',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:10:16.740Z',
#   'batchId': 285,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 7.936507936507937,
#   'durationMs': {'addBatch': 45,
#    'commitOffsets': 47,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 126,
#    'walCommit': 28},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 285,
#     'endOffset': 286,
#     'latestOffset': 286,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 7.936507936507937}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}}]

# %%
query.lastProgress['batchId']
# Out:
# 294

# %% [markdown]
# # Stop streaming

# %%
query.stop()

# %%
# awaitTermination

# %% [markdown]
# # Increase rows per second (rate)

# %%
# read stream
stream = spark.readStream.format("rate").option("rowsPerSecond", 20).load()

transformed = stream.withColumn("value2", F.col("value") * 2)

query = (transformed.writeStream
  .format('memory')
  .queryName('rate_report_2')
  .outputMode('append')
  .start()
)

# %%
print(spark.table("rate_report_2").count())
spark.table("rate_report_2").show(100, False)
# Out:
# 260
# +----------------------+-----+------+
# |timestamp             |value|value2|
# +----------------------+-----+------+
# |2024-11-23 14:21:32.11|0    |0     |
# |2024-11-23 14:21:32.16|1    |2     |
# |2024-11-23 14:21:32.21|2    |4     |
# |2024-11-23 14:21:32.26|3    |6     |
# |2024-11-23 14:21:32.31|4    |8     |
# |2024-11-23 14:21:32.36|5    |10    |
# |2024-11-23 14:21:32.41|6    |12    |
# |2024-11-23 14:21:32.46|7    |14    |
# |2024-11-23 14:21:32.51|8    |16    |
# |2024-11-23 14:21:32.56|9    |18    |
# |2024-11-23 14:21:32.61|10   |20    |
# |2024-11-23 14:21:32.66|11   |22    |
# |2024-11-23 14:21:32.71|12   |24    |
# |2024-11-23 14:21:32.76|13   |26    |
# |2024-11-23 14:21:32.81|14   |28    |
# |2024-11-23 14:21:32.86|15   |30    |
# |2024-11-23 14:21:32.91|16   |32    |
# |2024-11-23 14:21:32.96|17   |34    |
# |2024-11-23 14:21:33.01|18   |36    |
# |2024-11-23 14:21:33.06|19   |38    |
# |2024-11-23 14:21:33.11|20   |40    |
# |2024-11-23 14:21:33.16|21   |42    |
# |2024-11-23 14:21:33.21|22   |44    |
# |2024-11-23 14:21:33.26|23   |46    |
# |2024-11-23 14:21:33.31|24   |48    |
# |2024-11-23 14:21:33.36|25   |50    |
# |2024-11-23 14:21:33.41|26   |52    |
# |2024-11-23 14:21:33.46|27   |54    |
# |2024-11-23 14:21:33.51|28   |56    |
# |2024-11-23 14:21:33.56|29   |58    |
# |2024-11-23 14:21:33.61|30   |60    |
# |2024-11-23 14:21:33.66|31   |62    |
# |2024-11-23 14:21:33.71|32   |64    |
# |2024-11-23 14:21:33.76|33   |66    |
# |2024-11-23 14:21:33.81|34   |68    |
# |2024-11-23 14:21:33.86|35   |70    |
# |2024-11-23 14:21:33.91|36   |72    |
# |2024-11-23 14:21:33.96|37   |74    |
# |2024-11-23 14:21:34.01|38   |76    |
# |2024-11-23 14:21:34.06|39   |78    |
# |2024-11-23 14:21:34.11|40   |80    |
# |2024-11-23 14:21:34.16|41   |82    |
# |2024-11-23 14:21:34.21|42   |84    |
# |2024-11-23 14:21:34.26|43   |86    |
# |2024-11-23 14:21:34.31|44   |88    |
# |2024-11-23 14:21:34.36|45   |90    |
# |2024-11-23 14:21:34.41|46   |92    |
# |2024-11-23 14:21:34.46|47   |94    |
